# %%
import requests
import bs4
import html5lib

# %%
url=requests.get("https://cliksone.com")
print(type(url))
# Out:
# <class 'requests.models.Response'>

# %%
url.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en-US">\r\n<head>\r\n<meta charset="UTF-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<link rel="profile" href="https://gmpg.org/xfn/11">\r\n\r\n<title>Cliksone &#8211; All URL at one place</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Cliksone &raquo; Feed" href="https://cliksone.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Cliksone &raquo; Comments Feed" href="https://cliksone.com/comments/feed/" />\n\t\t<script>\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/cliksone.com\\/wp-includes\\/js\\/wp-emoji-re
# ...

# %%
soup=bs4.BeautifulSoup(url.text, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>Cliksone – All URL at one place</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://cliksone.com/feed/" rel="alternate" title="Cliksone » Feed" type="application/rss+xml"/>
# <link href="https://cliksone.com/comments/feed/" rel="alternate" title="Cliksone » Comments Feed" type="application/rss+xml"/>
# <script>
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/cliksone.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.7.2"}};
# ...

# %%
teet=soup.select('title')
print(teet)
# Out:
# [<title>Cliksone – All URL at one place</title>]

# %%
teet[0].getText()
# Out:
# 'Cliksone – All URL at one place'

# %%
soup.select('.screen-reader-text')
# Out:
# [<a class="skip-link screen-reader-text" href="#content">Skip to content</a>,
#  <span class="screen-reader-text">Main Menu</span>]

# %%
for i in soup.select('.screen-reader-text'):
    print(i.text)
# Out:
# Skip to content
# Main Menu
